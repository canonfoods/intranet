# %%
import pandas as pd
import os
import csv

# %%
file_to_load = "ContactList.csv"

contact_list_df = pd.read_csv(file_to_load)
print(contact_list_df)
# Out:
#                             Name                                   Position  \
# 0                Arthur Abrahams                          Managing Director
# 1                   Brad Johnson          Mechanical Maintenance Technician
# 2                Cameron Greaves  Production Scheduler/Inventory Controller
# 3                  Chris Conyers                         Operations Manager
# 4                  Chris Riordan          Electrical Maintenance Technician
# 5                     Craig Wood                     National Sales Manager
# 6                  Dispatch Room                                   Dispatch
# 7               Elaine Lightfoot            Sales Representative East Coast
# 8                   Emma Conyers                    Senior NPD Technologist
# 9                   Greg Malcolm            Queensland Warehouse Supervisor
# 10                 Hemant Sharma               Assistant Production Manager
# ...

# %%
html = contact_list_df.to_html(index=False)
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Name</th>
#       <th>Position</th>
#       <th>Ext</th>
#       <th>Mobile</th>
#       <th>Direct Number</th>
#       <th>Email</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Arthur Abrahams</td>
#       <td>Managing Director</td>
#       <td>8049</td>
#       <td>0424 158 719</td>
#       <td>+61 8 6499 9749</td>
#       <td>arthur@canonfoods.com.au</td>
#     </tr>
#     <tr>
#       <td>Brad Johnson</td>
#       <td>Mechanical Maintenance Technician</td>
#       <td>8053</td>
#       <td>0406 056 198</td>
#       <td>+61 8 6499 9753</td>
#       <td>brad@canonfoods.com.au</td>
#     </tr>
#     <tr>
#       <td>Cameron Greaves</td>
#       <td>Production Scheduler/Inventory Controller</td>
#       <td>8054</td>
#       <td>NaN</td>
#       <td>+61 8 6499 9754</td>
#       <td>cameron@canonfoods.com.au</td>
#     </tr>
#     <tr>
#       <td>Chris Conyers</td>
# ...

# %%
text_file = open("contactlist.html", "w")
text_file.write(html)
text_file.close()
